# %%
import os
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd

# %%
folder = "folder"
exp = 1

datasets = ["actor","chameleon","citeseer","community","computer","cora","cornell","cycle","grid","photo","pubmed","shape","squirrel","texas","wiki","wisconsin"]
folders = [folder+"/results/exp"+str(exp)+"_"+str(i) for i in range(20)]

dataset_name = []
trial = []
method = []
train_loss = []
train_accuracy = []
validation_loss = []
validation_accuracy = []
test_loss = []
test_accuracy = []
best_epoch = []
training_runtime = []
total_runtime = []
for i in range(len(folders)):
    directory_path = folders[i]
    all_files = []
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            all_files.append(file)
    for dataset in datasets:
        if dataset+"_gcn.pkl" in all_files:
            res = directory_path+"/"+dataset+"_gcn.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("GCN")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        # if dataset+"_gcn_mas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gcn_mas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GCN-MAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        # if dataset+"_gcn_tas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gcn_tas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GCN-TAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        if dataset+"_gat.pkl" in all_files:
            res = directory_path+"/"+dataset+"_gat.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("GAT")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        # if dataset+"_gat_mas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gat_mas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GAT-MAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        # if dataset+"_gat_tas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gat_tas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GAT-TAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        if dataset+"_sage.pkl" in all_files:
            res = directory_path+"/"+dataset+"_sage.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("GraphSAGE")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        # if dataset+"_sage_mas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_sage_mas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GraphSAGE-MAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        # if dataset+"_sage_tas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_sage_tas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GraphSAGE-TAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        if dataset+"_gps.pkl" in all_files:
            res = directory_path+"/"+dataset+"_gps.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("GraphGPS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        # if dataset+"_gps_mas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gps_mas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GraphGPS-MAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        # if dataset+"_gps_tas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_gps_tas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag6 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("GraphGPS-TAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        if dataset+"_san.pkl" in all_files:
            res = directory_path+"/"+dataset+"_san.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag5 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("SAN")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        # if dataset+"_san_mas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_san_mas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag5 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("SAN-MAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        # if dataset+"_san_tas.pkl" in all_files:
        #     res = directory_path+"/"+dataset+"_san_tas.pkl"
        #     with open(res, 'rb') as f:
        #         res = pickle.load(f)
        #     flag5 = True
        #     dataset_name.append(dataset)
        #     trial.append(i)
        #     method.append("SAN-TAS")
        #     epoch = res["best_epoch"]
        #     best_epoch.append(epoch)
        #     train_loss.append(res["training_results"][0][epoch-1])
        #     train_accuracy.append(res["training_results"][1][epoch-1])
        #     validation_loss.append(res["training_results"][2][epoch-1])
        #     validation_accuracy.append(res["training_results"][3][epoch-1])
        #     test_loss.append(res["test_loss"])
        #     test_accuracy.append(res["test_accuracy"])
        #     training_runtime.append(res["training_runtime"])
        #     total_runtime.append(res["total_runtime"])
        if dataset+"_nag.pkl" in all_files:
            res = directory_path+"/"+dataset+"_nag.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("NAG")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_nag_mas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_nag_mas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("NAG-MAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_nag_tas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_nag_tas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("NAG-TAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_vcr.pkl" in all_files:
            res = directory_path+"/"+dataset+"_vcr.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("VCR")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_vcr_mas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_vcr_mas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("VCR-MAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_vcr_tas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_vcr_tas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("VCR-TAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_cr_mas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_cr_mas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("CR-MAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
        if dataset+"_cr_tas.pkl" in all_files:
            res = directory_path+"/"+dataset+"_cr_tas.pkl"
            with open(res, 'rb') as f:
                res = pickle.load(f)
            flag6 = True
            dataset_name.append(dataset)
            trial.append(i)
            method.append("CR-TAS")
            epoch = res["best_epoch"]
            best_epoch.append(epoch)
            train_loss.append(res["training_results"][0][epoch-1])
            train_accuracy.append(res["training_results"][1][epoch-1])
            validation_loss.append(res["training_results"][2][epoch-1])
            validation_accuracy.append(res["training_results"][3][epoch-1])
            test_loss.append(res["test_loss"])
            test_accuracy.append(res["test_accuracy"])
            training_runtime.append(res["training_runtime"])
            total_runtime.append(res["total_runtime"])
data = {
    "dataset_name": dataset_name,
    "trial": trial,
    "method": method,
    "best_epoch": best_epoch,
    "train_loss": train_loss,
    "train_accuracy": train_accuracy,
    "validation_loss": validation_loss,
    "validation_accuracy": validation_accuracy,
    "test_loss": test_loss,
    "test_accuracy": test_accuracy,
    "training_runtime": training_runtime,
    "total_runtime": total_runtime
}

df = pd.DataFrame(data)
df = df.groupby(['dataset_name', 'method']).agg({
    'trial': ['count'],
    'best_epoch': ['min', 'max'],
    **{
        col: ['mean', 'std'] 
        for col in df.columns 
        if col not in ['dataset_name', 'method', 'best_epoch', 'trial']
    }
}).reset_index()

cwd = os.getcwd()
split_text = cwd.split('version')
df.to_excel('results_exp'+str(exp)+'.xlsx', index=True)

pd.set_option('display.max_rows', None)
print(df)
# Out:
#     dataset_name     method trial best_epoch       train_loss                \
#                             count        min   max       mean           std
# 0          actor     CR-MAS    20          7    13   0.000750  4.886536e-05
# 1          actor     CR-TAS    20         10    13   0.000698  1.874461e-05
# 2          actor        GAT    20         25    33   0.000390  3.839636e-06
# 3          actor        GCN    20         57    68   0.000372  5.101311e-06
# 4          actor   GraphGPS    20         18    21   0.000311  5.309737e-06
# 5          actor  GraphSAGE    20         51    54   0.000294  3.778187e-06
# 6          actor        NAG    20          6     8   0.000763  1.371186e-05
# 7          actor    NAG-MAS    20          7    10   0.000714  3.779559e-05
# 8          actor    NAG-TAS    20          7    10   0.000713  3.724602e-05
# 9          actor        SAN    20         14    17   0.000320  4.821855e-06
# 10         actor        VCR    20          7    53   0.000734  3.930193e-05
# 11         actor    VCR-MAS    20          6    13   0.000726  6.690915e-05
# 12         actor    VCR-TAS    20          6    64   0.000773  3.890849e-05
# 13     chameleon     CR-MAS    20         15    18   0.000768  6.878544e-05
# 14     chameleon     CR-TAS    20         15    19   0.000815  6.811646e-05
# 15     chameleon        GAT    20         31    49   0.000733  6.230370e-05
# 16     chameleon        GCN    20         66    91   0.000723  6.114188e-05
# 17     chameleon   GraphGPS    20         15    18   0.000312  4.022085e-05
# 18     chameleon  GraphSAGE    20         51    57   0.000255  3.032898e-05
# 19     chameleon        NAG    20         11    12   0.000899  3.956987e-05
# 20     chameleon    NAG-MAS    20         12    15   0.000707  6.715116e-05
# 21     chameleon    NAG-TAS    20         13    15   0.000673  4.637781e-05
# 22     chameleon        SAN    20         14    18   0.000331  6.264615e-05
# 23     chameleon        VCR    20          9    13   0.000853  7.557890e-05
# 24     chameleon    VCR-MAS    20         12    17   0.000616  8.478295e-05
# 25     chameleon    VCR-TAS    20         13    15   0.000600  4.123588e-05
# 26      citeseer     CR-MAS    20          7     9   0.001023  7.371079e-06
# 27      citeseer     CR-TAS    20          4    10   0.001023  1.142784e-05
# 28      citeseer        GAT    20         66    73   0.000270  1.756341e-05
# 29      citeseer        GCN    20        109   117   0.000229  9.598185e-06
# 30      citeseer   GraphGPS    20         22    24   0.000167  2.669902e-05
# 31      citeseer  GraphSAGE    20         87    96   0.000188  1.683738e-05
# 32      citeseer        NAG    20         13    15   0.000352  1.745655e-05
# 33      citeseer    NAG-MAS    20         12    13   0.000407  2.454733e-05
# 34      citeseer    NAG-TAS    20         12    14   0.000358  2.023447e-05
# 35      citeseer        SAN    20         20    23   0.000174  3.564759e-05
# 36      citeseer        VCR    20         14    16   0.000247  1.462147e-05
# 37      citeseer    VCR-MAS    20         10    12   0.000559  2.153061e-05
# 38      citeseer    VCR-TAS    20         10    14   0.000496  3.103645e-05
# 39     community     CR-MAS    20         22    31   0.001341  9.809817e-05
# 40     community     CR-TAS    20         29    42   0.000984  1.896074e-04
# 41     community        GAT    20        102   182   0.000923  7.713589e-05
# 42     community        GCN    20        167   229   0.001046  5.795349e-05
# 43     community   GraphGPS    20         17    27   0.001805  3.871106e-05
# 44     community  GraphSAGE    20         99   144   0.000736  1.738027e-04
# 45     community        NAG    20         22    31   0.001196  8.434920e-05
# 46     community    NAG-MAS    20         13    29   0.001551  1.479558e-04
# 47     community    NAG-TAS    20         13    29   0.001719  7.634854e-05
# 48     community        SAN    20         14    32   0.001546  1.798228e-04
# 49     community        VCR    20         14    28   0.001655  1.548076e-04
# 50     community    VCR-MAS    20         20    27   0.001185  9.254891e-05
# 51     community    VCR-TAS    20         19    29   0.001368  1.102806e-04
# 52      computer     CR-MAS    20         11    18   0.000148  2.171964e-05
# 53      computer     CR-TAS    20         11    32   0.000147  3.502642e-05
# 54      computer        GCN    20        134   266   0.000038  2.928424e-06
# 55      computer  GraphSAGE    20         90   151   0.000022  4.881071e-06
# 56      computer        NAG    20         12    24   0.000151  2.303634e-05
# 57      computer    NAG-MAS    20         11    24   0.000151  2.632077e-05
# 58      computer    NAG-TAS    20         12    38   0.000146  2.721436e-05
# 59      computer        VCR     1         20    20   0.000096           NaN
# 60      computer    VCR-MAS    11         11    19   0.000127  3.210752e-05
# 61      computer    VCR-TAS    18         11    16   0.000129  2.247570e-05
# 62          cora     CR-MAS    20          8    14   0.001321  1.817279e-05
# 63          cora     CR-TAS    20          5    13   0.001335  1.402904e-05
# 64          cora        GAT    20         78   100   0.000152  2.589317e-05
# 65          cora        GCN    20        136   157   0.000126  1.164836e-05
# 66          cora   GraphGPS    20         33    38   0.000048  1.000010e-05
# 67          cora  GraphSAGE    20         99   127   0.000071  1.970493e-05
# 68          cora        NAG    20         17    23   0.000173  3.859021e-05
# 69          cora    NAG-MAS    20         15    19   0.000202  3.977435e-05
# 70          cora    NAG-TAS    20         16    19   0.000169  2.476107e-05
# 71          cora        SAN    20         28    36   0.000074  4.929516e-05
# 72          cora        VCR    20         16    20   0.000196  1.860947e-05
# 73          cora    VCR-MAS    20         15    21   0.000315  3.664016e-05
# 74          cora    VCR-TAS    20         15    18   0.000293  2.808249e-05
# 75       cornell     CR-MAS    20         11    17   0.006207  1.612912e-03
# 76       cornell     CR-TAS    20         13    17   0.005718  1.288882e-03
# 77       cornell        GAT    20          3    15   0.010514  2.142000e-03
# 78       cornell        GCN    20          8    32   0.009611  2.411629e-03
# 79       cornell   GraphGPS    20         12    25   0.000909  5.363742e-04
# 80       cornell  GraphSAGE    20         21    39   0.002134  1.263544e-03
# 81       cornell        NAG    20         10    19   0.005009  2.177075e-03
# 82       cornell    NAG-MAS    20         10    17   0.004377  1.829060e-03
# 83       cornell    NAG-TAS    20          9    16   0.008241  2.121826e-03
# 84       cornell        SAN    20         10    22   0.000801  1.008861e-03
# 85       cornell        VCR    20         13    16   0.005572  1.016453e-03
# 86       cornell    VCR-MAS    20         11    17   0.005495  1.789523e-03
# 87       cornell    VCR-TAS    20         10    16   0.006206  1.799842e-03
# 88         cycle     CR-MAS    20          4   136   0.001537  1.885358e-05
# 89         cycle     CR-TAS    20         25    86   0.001479  3.810062e-05
# 90         cycle        GAT    20         11   129   0.001565  1.275695e-05
# 91         cycle        GCN    20         20   649   0.001528  1.703104e-04
# 92         cycle   GraphGPS    20         40   155   0.001530  4.605652e-05
# 93         cycle  GraphSAGE    20          5   115   0.001578  1.477218e-05
# 94         cycle        NAG    20         21    79   0.000214  9.322258e-05
# 95         cycle    NAG-MAS    20          5    76   0.001536  2.183775e-05
# 96         cycle    NAG-TAS    20         14   148   0.001497  3.932725e-05
# 97         cycle        SAN    20          2   124   0.001577  1.532200e-05
# 98         cycle        VCR    20         25   160   0.001315  1.774270e-04
# 99         cycle    VCR-MAS    20         33    99   0.001544  1.348227e-05
# 100        cycle    VCR-TAS    20          8   199   0.001564  1.377446e-05
# 101         grid     CR-MAS    20         26   143   0.001080  2.458094e-05
# 102         grid     CR-TAS    20         30    87   0.001080  2.826533e-05
# 103         grid        GAT    20         10   196   0.001103  7.796272e-06
# 104         grid        GCN    20          8   710   0.001080  8.961956e-05
# 105         grid   GraphGPS    20         38   195   0.001090  1.145383e-05
# 106         grid  GraphSAGE    20          9   111   0.001110  1.084475e-05
# 107         grid        NAG    20         34    93   0.000819  6.514929e-05
# 108         grid    NAG-MAS    20          1   162   0.001109  2.739017e-05
# 109         grid    NAG-TAS    20          1   174   0.001107  2.136905e-05
# 110         grid        SAN    20          6   165   0.001119  1.450505e-05
# 111         grid        VCR    20         21   176   0.001042  6.434499e-05
# 112         grid    VCR-MAS    20         16    60   0.001089  2.872792e-05
# 113         grid    VCR-TAS    20         20    53   0.001088  3.451721e-05
# 114        photo     CR-MAS    20         18    24   0.000062  1.351128e-05
# 115        photo     CR-TAS    20         20    30   0.000062  1.705016e-05
# 116        photo        GAT    20         72   116   0.000030  5.867977e-06
# 117        photo        GCN    20        108   228   0.000039  2.988983e-06
# 118        photo   GraphGPS    20         35    57   0.000026  5.834500e-06
# 119        photo  GraphSAGE    20         88   129   0.000010  3.695416e-06
# 120        photo        NAG    20         16    24   0.000060  1.626632e-05
# 121        photo    NAG-MAS    20         14    21   0.000082  1.660785e-05
# 122        photo    NAG-TAS    20         14    22   0.000079  1.655453e-05
# 123        photo        SAN    20         35    65   0.000019  7.289399e-06
# 124        photo        VCR    20         15    30   0.000065  2.690145e-05
# 125        photo    VCR-MAS    20         16    24   0.000073  1.889842e-05
# 126        photo    VCR-TAS    20         15    28   0.000067  1.936143e-05
# 127       pubmed     CR-MAS    13         15    21   0.000141  1.162957e-05
# 128       pubmed     CR-TAS     5         15    39   0.000136  2.780128e-05
# 129       pubmed        GAT    20        111   194   0.000031  1.980775e-06
# 130       pubmed        GCN    20        208   275   0.000029  8.128265e-07
# 131       pubmed  GraphSAGE    20        146   180   0.000023  9.267552e-07
# 132       pubmed        NAG    20          6     9   0.000145  1.132048e-05
# 133       pubmed    NAG-MAS    11          7    48   0.000132  7.318830e-06
# 134       pubmed    NAG-TAS    10          6    56   0.000130  9.657135e-06
# 135       pubmed        VCR    20         12   103   0.000120  1.894952e-05
# 136       pubmed    VCR-MAS     2         25    46   0.000128  4.058534e-05
# 137       pubmed    VCR-TAS     2         15    21   0.000126  2.380509e-05
# 138        shape     CR-MAS    20         21   124   0.002837  1.667343e-04
# 139        shape     CR-TAS    20         31    94   0.002267  4.398430e-04
# 140        shape        GAT    20         23   128   0.003677  6.348738e-05
# 141        shape        GCN    20         36  1006   0.001128  5.943337e-04
# 142        shape   GraphGPS    20         52   141   0.002563  2.526263e-04
# 143        shape  GraphSAGE    20         10   110   0.003704  6.057487e-05
# 144        shape        NAG    20         33   106   0.002414  2.012464e-04
# 145        shape    NAG-MAS    20         34    89   0.003138  9.458434e-05
# 146        shape    NAG-TAS    20         20    63   0.003149  1.643368e-04
# 147        shape        SAN    20          3   103   0.003714  6.323817e-05
# 148        shape        VCR    20         18   174   0.002909  4.371583e-04
# 149        shape    VCR-MAS    20          1   152   0.003657  1.021590e-04
# 150        shape    VCR-TAS    20         19    80   0.003685  5.400445e-04
# 151     squirrel     CR-MAS    20          7    11   0.000989  4.689112e-05
# 152     squirrel     CR-TAS    20          8    12   0.001010  5.185298e-05
# 153     squirrel        GCN    20         57    72   0.000480  1.367680e-05
# 154     squirrel   GraphGPS    20         13    16   0.000383  1.843729e-05
# 155     squirrel  GraphSAGE    20         42    47   0.000315  1.157094e-05
# 156     squirrel        NAG    20          5     7   0.001043  3.085287e-05
# 157     squirrel    NAG-MAS    20          6     8   0.000961  3.742611e-05
# 158     squirrel    NAG-TAS    20          6     8   0.000959  3.855155e-05
# 159     squirrel        SAN    20         13    14   0.000384  1.283165e-05
# 160     squirrel        VCR    14          6     9   0.000950  5.125801e-05
# 161     squirrel    VCR-MAS    20          6    10   0.000892  6.015708e-05
# 162     squirrel    VCR-TAS    20          6    10   0.000849  7.897260e-05
# 163        texas     CR-MAS    20         13    18   0.006096  1.772941e-03
# 164        texas     CR-TAS    20         14    18   0.004542  1.449056e-03
# 165        texas        GAT    20          6    18   0.010210  2.370936e-03
# 166        texas        GCN    20         10    31   0.008787  1.819064e-03
# 167        texas   GraphGPS    20         15    53   0.000660  5.446745e-04
# 168        texas  GraphSAGE    20         24    50   0.000607  7.405295e-04
# 169        texas        NAG    20          8    17   0.007101  2.068457e-03
# 170        texas    NAG-MAS    20         12    17   0.004322  1.194010e-03
# 171        texas    NAG-TAS    20          7    16   0.007218  2.205554e-03
# 172        texas        SAN    20         15    96   0.000390  3.830345e-04
# 173        texas        VCR    20         12    20   0.005428  1.938976e-03
# 174        texas    VCR-MAS    20         11    18   0.005968  1.606210e-03
# 175        texas    VCR-TAS    20         11    18   0.005309  1.845423e-03
# 176         wiki     CR-MAS    20         17    27   0.000221  2.022899e-05
# 177         wiki     CR-TAS    20         19    28   0.000222  1.646027e-05
# 178         wiki        GCN    20        231   348   0.000076  3.808925e-06
# 179         wiki   GraphGPS    20         62   114   0.000064  4.752581e-06
# 180         wiki  GraphSAGE    20        157   180   0.000053  2.783576e-06
# 181         wiki        NAG    20         16    28   0.000209  2.221658e-05
# 182         wiki    NAG-MAS    20         13    21   0.000239  2.477855e-05
# 183         wiki    NAG-TAS    20         15    24   0.000221  2.457310e-05
# 184         wiki        SAN     8         55    78   0.000054  8.860525e-06
# 185         wiki        VCR    13         15    24   0.000203  4.013305e-05
# 186         wiki    VCR-MAS    20         18    24   0.000219  2.078484e-05
# 187         wiki    VCR-TAS    20         17    24   0.000212  2.158696e-05
# 188    wisconsin     CR-MAS    20         12    22   0.003108  1.208718e-03
# 189    wisconsin     CR-TAS    20         14    20   0.002369  8.425874e-04
# 190    wisconsin        GAT    20          4    21   0.008134  1.620164e-03
# 191    wisconsin        GCN    20         18    40   0.006498  1.122864e-03
# 192    wisconsin   GraphGPS    20         14   143   0.000457  4.455149e-04
# 193    wisconsin  GraphSAGE    20         23    45   0.001222  6.060917e-04
# 194    wisconsin        NAG    20         12    20   0.002884  1.183887e-03
# 195    wisconsin    NAG-MAS    20         14    21   0.003075  1.060586e-03
# 196    wisconsin    NAG-TAS    20         11    19   0.004192  1.173018e-03
# 197    wisconsin        SAN    20         15    27   0.000222  1.612502e-04
# 198    wisconsin        VCR    20         13    20   0.003217  1.161075e-03
# 199    wisconsin    VCR-MAS    20         13    22   0.002878  1.121133e-03
# 200    wisconsin    VCR-TAS    20         13    19   0.003409  1.056029e-03
#
#     train_accuracy           validation_loss  ... validation_accuracy  \
#               mean       std            mean  ...                mean
# 0         0.382092  0.058264        0.000815  ...            0.301053
# 1         0.438632  0.022729        0.000775  ...            0.342632
# 2         0.374000  0.010952        0.000815  ...            0.287132
# 3         0.429474  0.011059        0.000807  ...            0.300368
# 4         0.521947  0.011252        0.000759  ...            0.350816
# 5         0.618092  0.006192        0.000752  ...            0.345632
# 6         0.376276  0.017487        0.000799  ...            0.310526
# 7         0.426145  0.039073        0.000782  ...            0.335684
# 8         0.424487  0.034301        0.000780  ...            0.336684
# 9         0.499145  0.011503        0.000751  ...            0.358737
# 10        0.400158  0.034888        0.000782  ...            0.326895
# 11        0.409197  0.073490        0.000808  ...            0.307342
# 12        0.363263  0.039826        0.000810  ...            0.298474
# 13        0.687039  0.034416        0.001993  ...            0.547188
# 14        0.672408  0.046568        0.002077  ...            0.501230
# 15        0.680185  0.026744        0.002024  ...            0.576801
# 16        0.707733  0.027809        0.002095  ...            0.563884
# 17        0.920694  0.011799        0.001937  ...            0.556063
# 18        0.956459  0.008836        0.001750  ...            0.639895
# 19        0.669508  0.023694        0.002361  ...            0.421529
# 20        0.727285  0.027094        0.001890  ...            0.581459
# 21        0.741696  0.021244        0.001900  ...            0.580668
# 22        0.908963  0.018679        0.001974  ...            0.552636
# 23        0.660281  0.032074        0.002251  ...            0.453339
# 24        0.761995  0.039476        0.001827  ...            0.612566
# 25        0.766696  0.016025        0.001822  ...            0.608963
# 26        0.294768  0.010767        0.002104  ...            0.219615
# 27        0.291491  0.021980        0.002103  ...            0.224970
# 28        0.862237  0.008058        0.000919  ...            0.751023
# 29        0.882231  0.004929        0.000893  ...            0.755656
# 30        0.916627  0.009488        0.000913  ...            0.750000
# 31        0.910884  0.008997        0.000880  ...            0.756558
# 32        0.814221  0.007887        0.000948  ...            0.748135
# 33        0.781600  0.011781        0.001051  ...            0.709146
# 34        0.812087  0.010232        0.000980  ...            0.730746
# 35        0.914071  0.010643        0.000971  ...            0.736282
# 36        0.874023  0.008128        0.000642  ...            0.843081
# 37        0.692634  0.007863        0.001220  ...            0.650722
# 38        0.722399  0.013907        0.001131  ...            0.683213
# 39        0.622286  0.029333        0.003289  ...            0.520286
# 40        0.728929  0.070616        0.002915  ...            0.583000
# 41        0.728143  0.021686        0.002772  ...            0.588429
# 153       0.504250  0.019420        0.001118  ...            0.393615
# 154       0.653923  0.025390        0.001159  ...            0.346500
# 155       0.769423  0.010046        0.001010  ...            0.451615
# 156       0.471750  0.021959        0.001152  ...            0.327385
# 157       0.531750  0.022255        0.001091  ...            0.397154
# 158       0.531788  0.018674        0.001090  ...            0.396577
# 159       0.649000  0.021891        0.001139  ...            0.361423
# 160       0.536896  0.024078        0.001129  ...            0.362473
# 161       0.559673  0.026394        0.001059  ...            0.426615
# 162       0.582981  0.036808        0.001055  ...            0.442654
# 163       0.839011  0.103595        0.022145  ...            0.617778
# 164       0.925275  0.050497        0.020083  ...            0.662222
# 165       0.671978  0.105480        0.026227  ...            0.563333
# 166       0.760440  0.081660        0.027645  ...            0.534444
# 167       0.992308  0.006277        0.011844  ...            0.808889
# 168       0.992857  0.013934        0.013481  ...            0.786667
# 169       0.769231  0.087186        0.023095  ...            0.608889
# 170       0.905495  0.045853        0.020671  ...            0.663333
# 171       0.799451  0.087395        0.022553  ...            0.610000
# 172       0.996154  0.006452        0.010631  ...            0.833333
# 173       0.868681  0.079761        0.020350  ...            0.650000
# 174       0.862637  0.063529        0.020737  ...            0.644444
# 175       0.859341  0.075176        0.019852  ...            0.648889
# 176       0.856872  0.014116        0.000387  ...            0.822051
# 177       0.854812  0.010840        0.000374  ...            0.823675
# 178       0.864829  0.005950        0.000197  ...            0.836154
# 179       0.873735  0.008653        0.000185  ...            0.827504
# 180       0.899197  0.005814        0.000167  ...            0.844103
# 181       0.866846  0.014998        0.000373  ...            0.830171
# 182       0.846923  0.015054        0.000395  ...            0.815915
# 183       0.857085  0.017551        0.000395  ...            0.818735
# 184       0.894893  0.017348        0.000167  ...            0.846282
# 185       0.871308  0.026031        0.000346  ...            0.842235
# 186       0.860308  0.012185        0.000379  ...            0.828615
# 187       0.865214  0.014774        0.000372  ...            0.832410
# 188       0.910400  0.066610        0.013592  ...            0.697581
# 189       0.954000  0.043731        0.012536  ...            0.725806
# 190       0.613200  0.089246        0.020077  ...            0.511290
# 191       0.724400  0.056953        0.020051  ...            0.525000
# 192       0.991200  0.010350        0.010056  ...            0.808065
# 193       0.970800  0.019122        0.011999  ...            0.745968
# 194       0.919200  0.046568        0.013408  ...            0.704839
# 195       0.907600  0.039744        0.012926  ...            0.722581
# 196       0.844000  0.058874        0.015431  ...            0.614516
# 197       0.997600  0.003761        0.008896  ...            0.828226
# 198       0.913600  0.050769        0.012883  ...            0.727419
# 199       0.918000  0.060364        0.012993  ...            0.720161
# 200       0.889600  0.051690        0.013948  ...            0.694355
#
#               test_loss           test_accuracy           training_runtime  \
#           std      mean       std          mean       std             mean
# 0    0.018510  0.000822  0.000010      0.294684  0.017427         7.588972
# 1    0.013150  0.000774  0.000013      0.342632  0.013175        10.692768
# 2    0.008266  0.000814  0.000004      0.288500  0.009540         3.847020
# 3    0.007351  0.000808  0.000004      0.295921  0.009130         1.221547
# 4    0.010601  0.000759  0.000009      0.354000  0.010868         9.859980
